# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
working_dir = '/content/drive/My Drive/UT_Austin/Diffusion_Models_Testing/generalization_in_diffusion_models_backup'

# %%
os.chdir(working_dir)

# %%
pip install tensorboardX
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 2.3 MB/s eta 0:00:00
# ...

# %%
#sample for image NCSN training
# !python code/score_based_image/scorenet_celeb_runner.py \
--set_size 1 \
--data_name img_align_celeba \
--noise_conditioning \
--batch_size 64 \
--num_epochs 6 \
--resume_training \
--ckpt_path models/ResScore/ncsn/img_align_celeba/0to255_set_size_1/checkpoint_epoch_7.pth
# Out:
# INFO:__main__:Noise levels: [1.         0.59948426 0.35938138 0.21544346 0.12915497 0.07742637
#  0.04641589 0.02782559 0.01668101 0.01      ]
# INFO:__main__:All data shape: torch.Size([198650, 1, 80, 80])
# INFO:__main__:Total samples: 198650, Midpoint: 99325
# INFO:root:Train set size: 1, Test set size: 1
# INFO:__main__:Train set shape: torch.Size([1, 1, 80, 80]), Test set shape: torch.Size([1, 1, 80, 80])
# INFO:__main__:Final train set shape: torch.Size([1, 1, 80, 80]), Test set shape: torch.Size([1, 1, 80, 80])
# INFO:__main__:Number of parameters: 5503937
# INFO:__main__:✓ resumed from models/ResScore/ncsn/img_align_celeba/0to255_set_size_1/checkpoint_epoch_7.pth
# INFO:__main__:Epoch: 0, Step: 10, Total Loss: 11.680171012878418
# INFO:__main__:Epoch: 0, Step: 20, Total Loss: 9.411636352539062
# INFO:__main__:Epoch: 0, Step: 30, Total Loss: 7.351308345794678
# INFO:__main__:Epoch: 0, Step: 40, Total Loss: 9.557442665100098
# ...

# %%
# !nvidia-smi
# Out:
# Sun May 18 14:28:13 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             46W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...
